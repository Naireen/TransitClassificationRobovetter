# %% [raw]
# Here, in this notebook, we develop the SNR features of the kplr injected files

# %%
import numpy as np
import pandas as pd
import os
import matplotlib
# %matplotlib inline
from matplotlib import pyplot as plt
import time
from scipy.optimize import brute

# %%
#'''
#the files processed with bls and light curves
file_name = "../../../Training/simulation/primaryinj1/prim.ls"
inj_order = np.loadtxt(file_name, dtype = str)[:10000] #only processsed first 10000 so far
inj_order

#load files from modshiftval folder and save all feats in a csvs files
# Out:
# array(['kplr001026032-0_prim.txt', 'kplr001026032-1_prim.txt',
#        'kplr001026032-2_prim.txt', ..., 'kplr006793728-6_prim.txt',
#        'kplr006793827-0_prim.txt', 'kplr006793827-1_prim.txt'],
#       dtype='|S24')

# %%
feat_files = np.zeros((10000,37))
#feat_file_list = os.listdir("../KplrInjModShiftVals/")
for i, name in enumerate(inj_order):
    data_name = name.split("_")[0]
    feat_file_name = data_name+"_prim_feats_fixed.txt"
    data = np.loadtxt("../KplrInjModShiftVals/"+feat_file_name)
    feat_files[i, :] =data
    if i%1000 == 999:
        print i
# Out:
# 999
# 1999
# 2999
# 3999
# 4999
# 5999
# 6999
# 7999
# 8999
# 9999

# %%
#file_list = os.listdir("../../Training/simulation/primaryKOI_try2/")
#generate the feature files from the 
#dont need to run this cell with the feature file generated.
#'''


#'''
col_names = ["star_id", "segment", "mod_sig_pri_dv", "mod_sig_sec_dv","mod_sig_ter_dv",
             "mod_sig_pos_dv", "mod_fa1_dv","mod_fa2_dv", "mod_fred_dv",
             "modshiftval1_dv", "modshiftval2_dv", "modshiftval3_dv",
             "modshiftval4_dv", "modshiftval5_dv", "modshiftval6_dv", 
             "white_noise", "red_noise", "BLS_Period_1_0", "BLS_Tc_1_0",
             "BLS_SN_1_0", "BLS_SR_1_0", "BLS_SDE_1_0", "BLS_Depth_1_0",
             "BLS_Qtran_1_0", "BLS_Qingress_1_0", "BLS_OOTmag_1_0",
             "BLS_i1_1_0", "BLS_i2_1_0", "BLS_deltaChi2_1_0", 
             "BLS_fraconenight_1_0", "BLS_Npointsintransit_1_0",
             "BLS_Ntransits_1_0", "BLS_Npointsbeforetransit_1_0", 
             "BLS_Npointsaftertransit_1_0", "BLS_Rednoise_1_0",
             "BLS_Whitenoise_1_0", "BLS_SignaltoPinknoise_1_0"]
feat_files_frame = pd.DataFrame(feat_files, columns=col_names)

#data_table = pd.DataFrame(data_table,columns=col_names )
#feat_files_frame.to_csv("../Data/Kplr_feat_files_10000.csv")
print feat_files_frame.shape
feat_files_frame.head()
#'''
# Out:
# (10000, 37)
#      star_id  segment  mod_sig_pri_dv  mod_sig_sec_dv  mod_sig_ter_dv  \
# 0  1026032.0      0.0         0.06869       -9.991249        0.009099
# 1  1026032.0      1.0         0.06987       -9.991297        0.008799
# 2  1026032.0      2.0         0.07517       -9.989414        0.011299
# 3  1026032.0      3.0         0.07313       -9.989979        0.010481
# 4  1026032.0      4.0         0.07558       -9.990860        0.009420
#
#    mod_sig_pos_dv  mod_fa1_dv  mod_fa2_dv  mod_fred_dv  modshiftval1_dv  \
# 0       -0.020914    3.361927    3.045619     1.248157        -3.306894
# 1       -0.010148    3.424279    3.027516     1.213860        -3.366719
# 2       -0.018384    3.422635    3.025687     1.261802        -3.363062
# 3       -0.016087    3.423239    3.026359     1.210633        -3.362833
# 4       -0.021778    3.418987    3.021628     1.209183        -3.356482
#
#              ...              BLS_i2_1_0  BLS_deltaChi2_1_0  \
# ...
